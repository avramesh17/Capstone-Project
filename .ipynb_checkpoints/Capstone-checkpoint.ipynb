# %%
#This notebook will be used mainly for the capstone project
#
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# # Clearly define data science problem and identify stakeholders
# INTRODUCTION / BUSINESS PROBLEM
#
# The problem that we will be aiming to figure out, through creating a model, if there is a way to advise drivers of potential future accidents by analyzing a combination of variables and predicting the collision severity. From the Data Collisions file provided, several potential indicators of an accident include Weather, Road conditions, and Light conditions. This model will be used to assist drivers and hopefully assist in detering accidents when driving conditions are less than ideal. I believe there is a need for solving this type of problem as often times it is unclear whether or not conditions for driving in certain areas lead to higher accident probability, and therefore collision severity.

# %% [markdown]
# # Describe the data you will be using to solve the problem
# DATA
#
# The data comes in a csv file with lots of columns that will not be used in our model. There are few variables(columns) that I believe will influence the model which include the Light Conditions(LIGHTCOND), the Road conditions(ROADCOND), and the Weather(WEATHER). The target column is Severity Code(SEVERITYCODE). Therefore the first step is going to be cleaning the data and selecting for the aforementioned columns. The next step will be to transform the values in some of the columns to respective integer values. For example, in respect to the column Road conditions, the values are 'Wet', 'Dry', and 'unknown' each of which can be mapped to a respective integer value of 1, 2, and 0. The same sort of methodology can be followed to map the values from Light Conditions, and Weather to numerical values.

# %%
df = pd.read_csv('Data-Collisions.csv') #read in the csv
df.head() #show first 5 entries
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
# 3  Matched         Block      NaN  ...      Dry                 Daylight
# 4  Matched  Intersection  34387.0  ...      Wet                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0           NaN         NaN      NaN         10
# 1           NaN   6354039.0      NaN         11
# 2           NaN   4323031.0      NaN         32
# 3           NaN         NaN      NaN         23
# 4           NaN   4028032.0      NaN         10
#
#                                           ST_COLDESC  SEGLANEKEY  \
# 0                                  Entering at angle           0
# 1  From same direction - both going straight - bo...           0
# 2                             One parked--one moving           0
# 3                   From same direction - all others           0
# 4                                  Entering at angle           0
#
#    CROSSWALKKEY  HITPARKEDCAR
# 0             0             N
# 1             0             N
# 2             0             N
# 3             0             N
# 4             0             N
#
# [5 rows x 38 columns]

# %% [markdown]
# As we can see there are 38 columns and clearly we do not need all of these so we will begin to clear the columns that are not necessary.

# %%
#initialize array with entries to drop
to_drop = ['X','Y', 'OBJECTID', 'INCKEY', 'COLDETKEY',
          'REPORTNO', 'STATUS', 'ADDRTYPE', 'INTKEY',
          'LOCATION', 'EXCEPTRSNCODE', 'EXCEPTRSNDESC',
          'PEDCOUNT', 'PEDCYLCOUNT', 'INCDATE', 'INCDTTM',
          'JUNCTIONTYPE', 'SDOT_COLCODE', 'SDOT_COLDESC', 
          'INATTENTIONIND', 'PEDROWNOTGRNT', 'SDOTCOLNUM', 
           'ST_COLCODE','ST_COLDESC', 'SEGLANEKEY', 'CROSSWALKKEY',
          'HITPARKEDCAR']

df.drop(to_drop,inplace=True,axis=1)

# %%
df.head()
# Out:
#    SEVERITYCODE  SEVERITYCODE.1                    SEVERITYDESC COLLISIONTYPE  \
# 0             2               2                Injury Collision        Angles
# 1             1               1  Property Damage Only Collision     Sideswipe
# 2             1               1  Property Damage Only Collision    Parked Car
# 3             1               1  Property Damage Only Collision         Other
# 4             2               2                Injury Collision        Angles
#
#    PERSONCOUNT  VEHCOUNT UNDERINFL   WEATHER ROADCOND  \
# 0            2         2         N  Overcast      Wet
# 1            2         2         0   Raining      Wet
# 2            4         3         0  Overcast      Dry
# 3            3         3         N     Clear      Dry
# 4            2         2         0   Raining      Wet
#
#                  LIGHTCOND SPEEDING
# 0                 Daylight      NaN
# 1  Dark - Street Lights On      NaN
# 2                 Daylight      NaN
# 3                 Daylight      NaN
# 4                 Daylight      NaN

# %% [markdown]
# This looks a lot better. There is a column called UNDERINF, which refers to drivers under the influence. This has values that could take on either a character value of 'Y' and 'N', as well as an integer value that can be 0 or greater. We want to remove rows where this column value is either 'Y', or has a value greater than 0.

# %%
to_drop= df[df['UNDERINFL'] == 'Y'].index
df.drop(to_drop, inplace=True)

# %%
df.head()
to_drop= df[df['UNDERINFL'] == '1'].index
df.drop(to_drop, inplace=True)
df.head()
# Out:
#    SEVERITYCODE  SEVERITYCODE.1                    SEVERITYDESC COLLISIONTYPE  \
# 0             2               2                Injury Collision        Angles
# 1             1               1  Property Damage Only Collision     Sideswipe
# 2             1               1  Property Damage Only Collision    Parked Car
# 3             1               1  Property Damage Only Collision         Other
# 4             2               2                Injury Collision        Angles
#
#    PERSONCOUNT  VEHCOUNT UNDERINFL   WEATHER ROADCOND  \
# 0            2         2         N  Overcast      Wet
# 1            2         2         0   Raining      Wet
# 2            4         3         0  Overcast      Dry
# 3            3         3         N     Clear      Dry
# 4            2         2         0   Raining      Wet
#
#                  LIGHTCOND SPEEDING
# 0                 Daylight      NaN
# 1  Dark - Street Lights On      NaN
# 2                 Daylight      NaN
# 3                 Daylight      NaN
# 4                 Daylight      NaN

# %% [markdown]
# Now that we are sure that the entries for drivers in our dataframe were not under the influence, we can go ahead and get rid of the column entirely. Additionally I am going to get rid of another column that has all NaN values.

# %%
to_drop = ['UNDERINFL', 'SPEEDING']
df.drop(to_drop, inplace=True, axis=1)
df.head()
# Out:
#    SEVERITYCODE  SEVERITYCODE.1                    SEVERITYDESC COLLISIONTYPE  \
# 0             2               2                Injury Collision        Angles
# 1             1               1  Property Damage Only Collision     Sideswipe
# 2             1               1  Property Damage Only Collision    Parked Car
# 3             1               1  Property Damage Only Collision         Other
# 4             2               2                Injury Collision        Angles
#
#    PERSONCOUNT  VEHCOUNT   WEATHER ROADCOND                LIGHTCOND
# 0            2         2  Overcast      Wet                 Daylight
# 1            2         2   Raining      Wet  Dark - Street Lights On
# 2            4         3  Overcast      Dry                 Daylight
# 3            3         3     Clear      Dry                 Daylight
# 4            2         2   Raining      Wet                 Daylight

# %%
to_drop = ['COLLISIONTYPE']
df.drop(to_drop, inplace=True, axis=1)
df.head()
# Out:
#    SEVERITYCODE  SEVERITYCODE.1                    SEVERITYDESC  PERSONCOUNT  \
# 0             2               2                Injury Collision            2
# 1             1               1  Property Damage Only Collision            2
# 2             1               1  Property Damage Only Collision            4
# 3             1               1  Property Damage Only Collision            3
# 4             2               2                Injury Collision            2
#
#    VEHCOUNT   WEATHER ROADCOND                LIGHTCOND
# 0         2  Overcast      Wet                 Daylight
# 1         2   Raining      Wet  Dark - Street Lights On
# 2         3  Overcast      Dry                 Daylight
# 3         3     Clear      Dry                 Daylight
# 4         2   Raining      Wet                 Daylight

# %%
to_drop = ['SEVERITYCODE.1']
df.drop(to_drop, inplace=True, axis=1)
df.head()
# Out:
#    SEVERITYCODE                    SEVERITYDESC  PERSONCOUNT  VEHCOUNT  \
# 0             2                Injury Collision            2         2
# 1             1  Property Damage Only Collision            2         2
# 2             1  Property Damage Only Collision            4         3
# 3             1  Property Damage Only Collision            3         3
# 4             2                Injury Collision            2         2
#
#     WEATHER ROADCOND                LIGHTCOND
# 0  Overcast      Wet                 Daylight
# 1   Raining      Wet  Dark - Street Lights On
# 2  Overcast      Dry                 Daylight
# 3     Clear      Dry                 Daylight
# 4   Raining      Wet                 Daylight

# %% [markdown]
# Now we can see the data looks a lot different than it did when we began, and is in a form much closer to one that can be used for training our model.

# %% [markdown]
# # Methodology
#
# We need to convert finally the Weather, Road condition, and Light condition to category variables. Once this is done, they are then in a suitable format for training the model. In order to use the scikit library's LabelEncoder, the respective rows need to be rid of empty strings. This can be fixed by turning the empty string into NaN and subsequently the LabelEncoder can be ran upon it.

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder


nan_value = float("NaN")

df.replace("", nan_value, inplace=True)

df.dropna(subset = ["WEATHER"], inplace=True)

labelencoder = LabelEncoder()
df['WEATHER-CAT'] = labelencoder.fit_transform(df['WEATHER'])
df.head()
# Out:
#    SEVERITYCODE                    SEVERITYDESC  PERSONCOUNT  VEHCOUNT  \
# 0             2                Injury Collision            2         2
# 1             1  Property Damage Only Collision            2         2
# 2             1  Property Damage Only Collision            4         3
# 3             1  Property Damage Only Collision            3         3
# 4             2                Injury Collision            2         2
#
#     WEATHER ROADCOND                LIGHTCOND  WEATHER-CAT
# 0  Overcast      Wet                 Daylight            4
# 1   Raining      Wet  Dark - Street Lights On            6
# 2  Overcast      Dry                 Daylight            4
# 3     Clear      Dry                 Daylight            1
# 4   Raining      Wet                 Daylight            6

# %%
df.dropna(subset = ["ROADCOND"], inplace=True)
labelencoder = LabelEncoder()
df['ROADCOND-CAT'] = labelencoder.fit_transform(df['ROADCOND'])
df.head()
# Out:
#    SEVERITYCODE                    SEVERITYDESC  PERSONCOUNT  VEHCOUNT  \
# 0             2                Injury Collision            2         2
# 1             1  Property Damage Only Collision            2         2
# 2             1  Property Damage Only Collision            4         3
# 3             1  Property Damage Only Collision            3         3
# 4             2                Injury Collision            2         2
#
#     WEATHER ROADCOND                LIGHTCOND  WEATHER-CAT  ROADCOND-CAT
# 0  Overcast      Wet                 Daylight            4             8
# 1   Raining      Wet  Dark - Street Lights On            6             8
# 2  Overcast      Dry                 Daylight            4             0
# 3     Clear      Dry                 Daylight            1             0
# 4   Raining      Wet                 Daylight            6             8

# %%
df.dropna(subset = ["LIGHTCOND"], inplace=True)
labelencoder = LabelEncoder()
df['LIGHTCOND-CAT'] = labelencoder.fit_transform(df['LIGHTCOND'])
df.head()
# Out:
#    SEVERITYCODE                    SEVERITYDESC  PERSONCOUNT  VEHCOUNT  \
# 0             2                Injury Collision            2         2
# 1             1  Property Damage Only Collision            2         2
# 2             1  Property Damage Only Collision            4         3
# 3             1  Property Damage Only Collision            3         3
# 4             2                Injury Collision            2         2
#
#     WEATHER ROADCOND                LIGHTCOND  WEATHER-CAT  ROADCOND-CAT  \
# 0  Overcast      Wet                 Daylight            4             8
# 1   Raining      Wet  Dark - Street Lights On            6             8
# 2  Overcast      Dry                 Daylight            4             0
# 3     Clear      Dry                 Daylight            1             0
# 4   Raining      Wet                 Daylight            6             8
#
#    LIGHTCOND-CAT
# 0              5
# 1              2
# 2              5
# 3              5
# 4              5

# %%
df.dtypes
# Out:
# SEVERITYCODE      int64
# SEVERITYDESC     object
# PERSONCOUNT       int64
# VEHCOUNT          int64
# WEATHER          object
# ROADCOND         object
# LIGHTCOND        object
# WEATHER-CAT       int64
# ROADCOND-CAT      int64
# LIGHTCOND-CAT     int64
# dtype: object

# %% [markdown]
# Now that we have the severity code in a int64 format, as well as roadcond-cat, lightcond-cat, and weather-cat, we can go ahead and start with the machine learning process.
#
# There are 3 different types of Machine Learning models we will be working with, KNN, Decision Tree, and Logistic Regression.
#
# We will be using KNN to
#
#
# We will use the Decision Tree to
#
#
# Finally, we will use Logistic Regression to

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

Feature = df[['WEATHER-CAT', 'ROADCOND-CAT', 'LIGHTCOND-CAT']]
#Feature[0:5]

Y = df[['SEVERITYCODE']]
#Y[0:5]
X = preprocessing.StandardScaler().fit(Feature).transform(Feature) #Normalize your data
X[0:5]
# Out:
# array([[ 0.30871036,  1.47583065,  0.30682525],
#        [ 1.00272147,  1.47583065, -1.47564961],
#        [ 0.30871036, -0.7149397 ,  0.30682525],
#        [-0.7323063 , -0.7149397 ,  0.30682525],
#        [ 1.00272147,  1.47583065,  0.30682525]])

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=4) #we will use 30% for training
X_test
# Out:
# array([[ 1.00272147,  1.47583065, -0.28733303],
#        [-0.7323063 , -0.7149397 ,  0.30682525],
#        [ 1.00272147,  1.47583065,  0.30682525],
#        ...,
#        [-0.7323063 , -0.7149397 , -1.47564961],
#        [-0.7323063 , -0.7149397 , -1.47564961],
#        [ 1.00272147,  1.47583065,  0.30682525]])

# %%
from sklearn.neighbors import KNeighborsClassifier

k = 9 #3 values of k were tried, k= 9,19,29. k=9 had array([1,2,1,1,1]) while k=19 and k=29 had an array of 1's
standard_accuracy = np.zeros((k-1))
mean_accuracy = np.zeros((k-1))

neighbor = KNeighborsClassifier(n_neighbors = k).fit(X_train, y_train)
neighbor

knn_yhat = neighbor.predict(X_test)
knn_yhat[0:5]
# Out:
# /Users/anirramesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   import sys
# array([1, 2, 1, 1, 1])

# %%
k=9
plt.plot(range(1,k),mean_accuracy,'g')
plt.fill_between(range(1,k),mean_accuracy - 1 * standard_accuracy, mean_accuracy + 1 * standard_accuracy, alpha=0.20)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Neighbors (K)')
plt.tight_layout()
plt.show()
print( "The best accuracy was with", mean_accuracy.max(), "with k=", mean_accuracy.argmax()+1)
# Out:
# The best accuracy was with 0.0 with k= 1

# %% [markdown]
# Next I will be trying to work with a Decision Tree to see what type of results we can obtain from this model.

# %%
from sklearn.tree import DecisionTreeClassifier

newTree = DecisionTreeClassifier(criterion="entropy", max_depth = 200)
newTree
newTree.fit(X_train,y_train)
dt_yhat = newTree.predict(X_test)

# %%
print(dt_yhat[0:5]) #print first 5 predictions
print(y_test[0:5]) #compare to first 5 from y test.
# Out:
# [1 1 1 1 1]
#         SEVERITYCODE
# 183978             2
# 106469             1
# 165764             1
# 76996              1
# 51907              1

# %% [markdown]
# Now that we have worked with training the model using both KNN as well as Decision Tree, the final method that we will be using today is Logistic Regression.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=8, solver='liblinear').fit(X_train,y_train.values.ravel())
LR
# Out:
# LogisticRegression(C=8, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# Lets go ahead and calculate the yhat for the linear regression model

# %%
lr_yhat = LR.predict(X_test)
lr_yhat
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
yhat_probability = LR.predict_proba(X_test)
yhat_probability
# Out:
# array([[0.73054639, 0.26945361],
#        [0.67725045, 0.32274955],
#        [0.73773317, 0.26226683],
#        ...,
#        [0.65264698, 0.34735302],
#        [0.65264698, 0.34735302],
#        [0.73773317, 0.26226683]])

# %% [markdown]
# Model Evaluation using the Test set can now be can. We will run the three different tests.

# %%
from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

#for knn
from sklearn.metrics import classification_report
cr = classification_report(y_test, yhat)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.73      0.61      0.67     38033
#            2       0.34      0.47      0.39     16039
#
#     accuracy                           0.57     54072
#    macro avg       0.54      0.54      0.53     54072
# weighted avg       0.62      0.57      0.59     54072

# %%
#for LR
classification_report(y_test, lr_yhat)
print('Logistic Regression', classification_report(y_test, lr_yhat))
# Out:
# Logistic Regression               precision    recall  f1-score   support
#
#            1       0.70      1.00      0.83     38033
#            2       0.00      0.00      0.00     16039
#
#     accuracy                           0.70     54072
#    macro avg       0.35      0.50      0.41     54072
# weighted avg       0.49      0.70      0.58     54072
# /Users/anirramesh/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#for decision tree
predTree = newTree.predict(X_test)
print("Decision Trees's Accuracy was: ", metrics.accuracy_score(y_test, predTree))
# Out:
# Decision Trees's Accuracy was:  0.7031920402426395
